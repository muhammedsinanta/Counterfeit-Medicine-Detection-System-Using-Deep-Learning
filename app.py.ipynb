# %%
import streamlit as st
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

model=load_model("medicine_model.keras")

st.title("Counterfeit Medicine Detection")

uploaded_file=st.file_uploader(
    "Upload Medicine Image",
    type=["jpg","png","jpeg"]
)

if uploaded_file:

    img=image.load_img(uploaded_file,target_size=(224,224))

    st.image(uploaded_file)

    img=image.img_to_array(img)

    img=np.expand_dims(img,axis=0)

    img=img/255

    pred=model.predict(img)

    if pred[0][0]>0.5:
        st.success("Real Medicine")
    else:
        st.error("Fake Medicine")
# Out:
# 2026-07-06 16:40:52.015 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 16:40:54.733
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Cnaan\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-07-06 16:40:54.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 16:40:54.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 16:40:54.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 16:40:54.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 16:40:54.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 16:40:54.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 16:40:54.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 16:40:54.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
